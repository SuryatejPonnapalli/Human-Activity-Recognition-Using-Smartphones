# %% [markdown]
# # Model Building
# We have observed a total of 561 features, which is a lot, so let us first find the most important features using RandomForestClassifier, then use a Multiclass Classification Model to classify with reduced features.

# %%
! pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in /Users/suryatejponnapalli/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from scikit-learn) (2.2.5)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.3 MB/s eta 0:00:00
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp311-cp311-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 977.0 kB/s eta 0:00:0000:0100:01
# Downloading joblib-1.5.0-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.15.3-cp311-cp311-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 1.4 MB/s eta 0:00:0000:0100:01m
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.0 scikit-learn-1.6.1 scipy-1.15.3 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
import pandas as pd

df = pd.read_csv('../data/processed/train.csv')
drop_selected = ["subject","Activity","ActivityName"]
x_train = df.drop(columns = drop_selected)
y_train = df["Activity"]

# %%
rfc = RandomForestClassifier(n_estimators=100, random_state = 42)
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
import numpy as np

importances = rfc.feature_importances_
indices = np.argsort(importances)[::-1]

# %%
N = 100
top_indices = indices[:N]
top_feature_names = x_train.columns[top_indices]

x_train_selected = x_train[top_feature_names]

print("Top", N, "features:")
print(top_feature_names.tolist())
# Out:
# Top 100 features:
# ['tGravityAcc-mean()-X', 'tGravityAcc-max()-X', 'angle(X,gravityMean)', 'tGravityAcc-mean()-Y', 'tGravityAcc-energy()-X', 'angle(Y,gravityMean)', 'tGravityAcc-min()-X', 'tGravityAcc-min()-Y', 'tGravityAcc-max()-Y', 'tGravityAcc-energy()-Y', 'tBodyAccJerk-std()-X', 'angle(Z,gravityMean)', 'tGravityAcc-arCoeff()-Z,2', 'fBodyAccMag-energy()', 'tGravityAccMag-std()', 'fBodyAccJerk-bandsEnergy()-1,16', 'tGravityAcc-energy()-Z', 'fBodyAccJerk-bandsEnergy()-1,16.1', 'fBodyAccJerk-max()-X', 'tBodyAccMag-std()', 'fBodyAcc-mean()-X', 'tGravityAcc-mean()-Z', 'tGravityAcc-min()-Z', 'fBodyAccMag-mad()', 'tGravityAcc-arCoeff()-Z,1', 'fBodyAccJerk-energy()-X', 'fBodyAccJerk-bandsEnergy()-1,24', 'tBodyAccJerkMag-energy()', 'fBodyAcc-bandsEnergy()-1,24', 'fBodyAcc-entropy()-X', 'tBodyAccJerk-sma()', 'tBodyGyroJerk-iqr()-Z', 'tGravityAcc-entropy()-Y', 'tBodyAcc-correlation()-X,Y', 'fBodyAcc-mad()-X', 'tGravityAcc-arCoeff()-Y,1', 'tGravityAcc-arCoeff()-X,2', 'tBodyAccJerk-mad()-Y', 'fBodyAccJerk-mean()-X', 'tGravityAcc-arCoeff()-Y,2', 'tBodyGyroJerk-iqr()-X', 'tBodyGyroJerk-mad()-Z', 'tBodyGyroJerk-sma()', 'fBodyAccJerk-std()-X', 'tGravityAcc-arCoeff()-Z,3', 'tGravityAcc-arCoeff()-X,1', 'tBodyAcc-std()-X', 'fBodyAccJerk-bandsEnergy()-1,8', 'tBodyAccMag-arCoeff()1', 'fBodyAcc-bandsEnergy()-1,8', 'fBodyAcc-bandsEnergy()-1,16', 'tGravityAccMag-arCoeff()1', 'fBodyAccMag-std()', 'tBodyAcc-energy()-X', 'tGravityAcc-arCoeff()-Z,4', 'tBodyAccJerk-energy()-X', 'fBodyAccJerk-max()-Y', 'tGravityAcc-arCoeff()-Y,3', 'tBodyAcc-max()-X', 'tGravityAcc-max()-Z', 'fBodyAccJerk-mad()-X', 'tBodyGyroJerkMag-mean()', 'tBodyAccJerkMag-sma()', 'fBodyAccJerk-bandsEnergy()-9,16', 'tBodyAccJerk-iqr()-Y', 'tBodyAccJerk-iqr()-X', 'fBodyAccJerk-mean()-Y', 'fBodyAcc-std()-X', 'fBodyAcc-energy()-X', 'tBodyAccMag-mad()', 'tGravityAccMag-mad()', 'tBodyAccJerk-max()-X', 'tGravityAcc-sma()', 'fBodyAccMag-mean()', 'tGravityAcc-arCoeff()-X,3', 'fBodyGyro-std()-X', 'fBodyGyro-bandsEnergy()-1,8', 'fBodyAccMag-entropy()', 'tBodyGyro-max()-X', 'fBodyGyro-maxInds-Z', 'fBodyAcc-bandsEnergy()-9,16', 'tBodyGyro-entropy()-X', 'fBodyGyro-mad()-X', 'tBodyAcc-correlation()-Y,Z', 'fBodyGyro-max()-X', 'fBodyAccMag-sma()', 'tGravityAcc-arCoeff()-X,4', 'fBodyGyro-meanFreq()-X', 'tGravityAcc-arCoeff()-Y,4', 'fBodyAcc-meanFreq()-Z', 'tBodyAccMag-arCoeff()2', 'tBodyAccMag-max()', 'tBodyGyroJerk-energy()-X', 'tGravityAcc-correlation()-X,Y', 'fBodyAccMag-max()', 'tBodyGyro-mad()-X', 'fBodyAccJerk-sma()', 'fBodyGyro-mean()-X', 'tBodyGyro-energy()-X', 'fBodyGyro-maxInds-Y']

# %%
with open('top_features.txt', 'w') as f:
    for feature in top_feature_names:
        f.write(f"{feature}\n")

print(f"Top features saved to 'top_features.txt'.")
# Out:
# Top features saved to 'top_features.txt'.
